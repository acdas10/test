# %%
conda env create -f environment.yml
# Out:
# ...
# Solving environment: ...working... done
#
# ...
#
# pytz-2022.1          | 242 KB    |            |   0%
# pytz-2022.1          | 242 KB    | 6          |   7%
# pytz-2022.1          | 242 KB    | ########## | 100%
#
# freetype-2.10.4      | 489 KB    |            |   0%
# freetype-2.10.4      | 489 KB    | ########## | 100%
#
# m2w64-libwinpthread- | 31 KB     |            |   0%
# m2w64-libwinpthread- | 31 KB     | ########## | 100%
#
# m2w64-gcc-libs-core- | 214 KB    |            |   0%
# m2w64-gcc-libs-core- | 214 KB    | ########## | 100%
#
# jpeg-9e              | 366 KB    |            |   0%
# jpeg-9e              | 366 KB    | ########## | 100%
#
# libbrotlidec-1.0.9   | 33 KB     |            |   0%
# libbrotlidec-1.0.9   | 33 KB     | ########## | 100%
#
# openjpeg-2.4.0       | 238 KB    |            |   0%
# openjpeg-2.4.0       | 238 KB    | ########## | 100%
#
# six-1.16.0           | 14 KB     |            |   0%
# six-1.16.0           | 14 KB     | ########## | 100%
#
# ...

# %%
 "cells": [
  {
   "cell_type": "markdown",
   "id": "730fcf43-2ed7-4a37-a01c-5e8dd2bf7209",
   "metadata": {},
   "source": [
    "# Exercise 0: Check your setup and load an image\n",
    "\n"
   ]
  }
# Out:
#   File "<ipython-input-6-9cf7c7313b5a>", line 10
#     }
#      ^
# SyntaxError: unexpected EOF while parsing

# %%
conda env list
# Out:
# # conda environments:
# #
# base                  *  C:\Users\ashik\anaconda3
# cv_tut                   C:\Users\ashik\anaconda3\envs\cv_tut
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "id": "730fcf43-2ed7-4a37-a01c-5e8dd2bf7209",
   "metadata": {},
   "source": [
    "# Exercise 0: Check your setup and load an image\n",
    "\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 1,
   "id": "84b2b05d-7c0e-442f-8bb8-373770b925e0",
   "metadata": {},
   "outputs": [],
   "source": [
    "#Basic setup and imports\n",
    "%load_ext autoreload\n",
    "%autoreload 2\n",
    "%matplotlib widget\n",
    "\n",
    "import time\n",
    "import os\n",
    "import pickle\n",
    "\n",
    "import cv2\n",
    "from PIL import Image\n",
    "\n",
    "import numpy as np\n",
    "import scipy.spatial.distance as ssd\n",
    "import scipy.cluster as cl\n",
    "import scipy.spatial as sp\n",
    "\n",
    "import matplotlib.pyplot as plt\n",
    "import matplotlib.cm as cm\n",
    "from matplotlib.lines import Line2D\n",
    "from matplotlib.patches import Circle, Rectangle\n",
    "from IPython import display"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "05957302-7b71-428c-a85d-4123cee0476a",
   "metadata": {},
   "source": [
    "In your data folder you should put the image `green_cat.jpeg`. We use OpenCV to load the image:\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 2,
   "id": "9b91240d-2588-47c8-84f0-16056c6460eb",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "<matplotlib.image.AxesImage at 0x7f814aa35960>"
      ]
     },
     "execution_count": 2,
     "metadata": {},
     "output_type": "execute_result"
    },
    {
     "data": {
      "application/vnd.jupyter.widget-view+json": {
       "model_id": "4ac26c744c1940ddbec3b35f89c032c1",
       "version_major": 2,
       "version_minor": 0
      }
# Out:
#   File "<ipython-input-3-147f30f3c782>", line 73
#     }
#      ^
# SyntaxError: unexpected EOF while parsing
